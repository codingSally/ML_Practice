# %%
import numpy as np

from Logistic import *

# %%
dataArr, lableMat = Logistic.loadDataSet()

# %%
weights = Logistic.gradAscent(Logistic, dataArr, lableMat)

# %%
Logistic.plotBestFit(Logistic, weights.getA()) # getA Return self as an ndarray object.Equivalent to np.asarray(self).

# %%
weights_2 = Logistic.stocGradAscent0(Logistic, np.array(dataArr), lableMat)
Logistic.plotBestFit(Logistic, weights_2) # getA Return self as an ndarray object.Equivalent to np.asarray(self).

# %%
weights_3 = Logistic.stocGradAscent1(Logistic, np.array(dataArr), lableMat)
Logistic.plotBestFit(Logistic, weights_3) # getA Return self as an ndarray object.Equivalent to np.asarray(self).

# %%
# Logistic.multiTest(Logistic)
